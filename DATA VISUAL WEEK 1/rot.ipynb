# %%
import numpy as np
import json

# %%
np.random.seed(42)
total=1000

# %%
x=np.random.uniform(-400,400,total)
y=np.random.uniform(-400,400,total)
z=np.random.uniform(-400,400,total)
print(x[:3])
print(y[:3])
print(z[:3])
# Out:
# [-100.36790492  360.57144513  185.59515345]
# [-251.89365693   33.5207579   298.3566687 ]
# [-190.63545301 -202.41696074  325.00366442]

# %%
points=[]
for nums in range (total):
    points.append({"x":float(x[nums]),
                   "y":float(y[nums]),
                   "z":float(z[nums])})

# %%
print(points[:4])
# Out:
# [{'x': -100.36790492211003, 'y': -100.36790492211003, 'z': -100.36790492211003}, {'x': 360.571445127933, 'y': 360.571445127933, 'z': 360.571445127933}, {'x': 185.59515344912404, 'y': 185.59515344912404, 'z': 185.59515344912404}, {'x': 78.92678735762928, 'y': 78.92678735762928, 'z': 78.92678735762928}]

# %%
with open("data.json","w")as file:
    data=json.dump(points,file,indent=4)
print(f"{total} data generated successfully")
# Out:
# 1000 data generated successfully
